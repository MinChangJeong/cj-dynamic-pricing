# %%
# %run "./preprocessing.ipynb"
# Out:
# Done !!

# %%
import warnings
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import Dense, Input, LSTM, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.metrics import mean_absolute_error, mean_squared_error
import pickle
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

tf.__version__
warnings.filterwarnings(action='ignore')

# %%
e_commerce_fc_data.head(1)
# Out:
#                       창고코드     주문 날짜  주문 시간     고객사코드  품목수량      입력자ID  권역구분  \
# 2021-03-03 03:55:21  KX007  20210303  35521  90001441     1  iNEXBatch  50.0
#
#                     송화인주소1 송화인주소2 수화인주소1  ...            datetime   송화인터미널  \
# 2021-03-03 03:55:21    경기도    광주시   경상남도  ... 2021-03-03 03:55:21  경기도 광주시
#
#                        수화인터미널 SHPR_ADDR_LATITUDE  SHPR_ADDR_LONGITUDE  \
# 2021-03-03 03:55:21  경상남도 김해시             37.403              127.239
#
#                      SHPR_ADDR_HUBS CNEE_ADDR_LATITUDE  CNEE_ADDR_LONGITUDE  \
# 2021-03-03 03:55:21          분당ASub             35.236              128.831
#
#                      CNEE_ADDR_HUBS    distance
# 2021-03-03 03:55:21          김해ASub  340.199185
#
# [1 rows x 21 columns]

# %%
np.random.seed(seed=42)    
random_number = np.random.randint(0, len(e_commerce_fc_data), 150000)

selected_data = e_commerce_fc_data.iloc[random_number, :][["datetime", "고객사코드", "distance"]]

# %%
### 출고량 별 세분화 
def set_fee(selected):
    code_fee_ = {
        100000 : 0,
        50000 : 20,
        30000 : 40,
        20000 : 60,
        10000 : 80,
        5000 : 100,
        3000 : 120,
        2000 : 140,
        1000 : 160,
        500 : 180,
        0 : 200
    }

    code_list = {
        90001302 : 100000,
        90001542 : 100000,
        90001341 : 100000,
        90001541 : 100000,
        90001441 : 100000,
        90001602 : 100000,
        90001443 : 100000,
        90001582 : 81950,
        90001622 : 68074,
        90001521 : 58814,
        90001682 : 36071,
        90001702 : 30606,
        90001776 : 24318,
        90001705 : 23976,
        90001704 : 20317,
        90001768 : 12844,
        90001662 : 8126,
        90001683 : 5850,
        90001381 : 5438,
        90001703 : 2416,
        90001664 : 1904,
        90001502 : 133,
        90001765 : 48,
        90001842 : 44,
        90001562 : 10,
        90001774 : 7,
        90001802 : 6
    }

    ### 거리별  세분화
    distance_fee_ = {
        400 : 500,
        300 : 400,
        100 : 300,
        50 : 200,
        0 : 0
    }

    ### 시간별 세분화
    time_fee_ = {
        400 : [1, 2, 11, 12, 13],
        200 : [0, 3, 4, 10, 14],
        100 : [5, 6, 7, 8, 9, 15, 23],
        0 : [16, 17, 18, 19, 20, 21, 22]
    }

    str_target_code = []
    make_code_fee_ = []
    make_distance_fee_ = []
    make_time_fee_ = []
    make_fee_ = []
    code_values = []
    code_fee_key = list(code_fee_.keys())
    distance_fee_key = list(distance_fee_.keys())
    time_fee_key = list(time_fee_.keys())

    for i in range(len(selected)):
        target_code = selected["고객사코드"][i]
        target_distance = selected["distance"][i]
        target_day = selected["datetime"][i]
        str_target_code.append(str(target_code))

        ## code fee_ 
        code_value = code_list[target_code]

        if code_value == 100000:
            set_code_fee = 0
            make_code_fee_.append(set_code_fee)
            code_values.append(code_value)
        else:
            for i in range(len(code_fee_key) -1 ):

                if (code_fee_key[i] > code_value) and ( code_fee_key[i+1] <= code_value) :
                    set_code_fee = code_fee_[code_fee_key[i+1]]
                    set_code_fee = set_code_fee + (code_fee_[code_fee_key[i+1]] - code_fee_[code_fee_key[i]]) * ( (code_value - code_fee_key[i+1]) / (code_fee_key[i] - code_fee_key[i+1]) )

                    if set_code_fee > 200:
                        set_code_fee = 200

                    make_code_fee_.append(int(set_code_fee))
                    code_values.append(code_value)

                else:
                    pass

        ## distance fee_
        if target_distance >= distance_fee_key[0]:
            set_distance_fee = 500
            make_distance_fee_.append(set_distance_fee)
        else:
            for i in range(len(distance_fee_key) -1 ):
                if (distance_fee_key[i] > target_distance) and ( distance_fee_key[i+1] <= target_distance):
                    set_distance_fee = distance_fee_[distance_fee_key[i+1]]
                    set_distance_fee = set_distance_fee + (distance_fee_[distance_fee_key[i+1]] - distance_fee_[distance_fee_key[i]]) * (( target_distance - distance_fee_key[i+1]) / ( distance_fee_key[i] - distance_fee_key[i+1]) )

                    if set_distance_fee > 500:
                        set_distance_fee = 200

                    if set_distance_fee < 0:
                        set_distance_fee = 0
                        
                    make_distance_fee_.append(int(set_distance_fee))
                else:
                    pass

        ## day fee_

        day_value = target_day.hour

        for i in time_fee_key:
            if day_value in time_fee_[i]:
                set_day_fee = i
                make_time_fee_.append(set_day_fee)            
            else:
                pass

    print(len(make_code_fee_))
    print(len(make_distance_fee_))
    print(len(make_time_fee_))    
    for i in range(len(selected)):
        make_fee_.append(
            make_code_fee_[i]
            + make_distance_fee_[i]
            + make_time_fee_[i]
        )


    selected["result"] = make_fee_
    selected["code"] = make_code_fee_
    selected["str_code"] = str_target_code
    selected["code_value"] = code_values
    return selected

# %%
set_fee_df = set_fee(selected_data)
# Out:
# 150000
# 150000
# 150000

# %%
### 출고량 별 세분화 
class set_fee():
    def __init__(self, array):
        self.distance = array[0] 
        self.time = array[1]
        self.quantity = array[2]

    def set_fee(self, ):
        code_fee_ = {
            100000 : 0,
            50000 : 20,
            30000 : 40,
            20000 : 60,
            10000 : 80,
            5000 : 100,
            3000 : 120,
            2000 : 140,
            1000 : 160,
            500 : 180,
            0 : 200
        }

        ### 거리별  세분화
        distance_fee_ = {
            400 : 500,
            300 : 400,
            100 : 300,
            50 : 200,
            0 : 0
        }

        ### 시간별 세분화
        time_fee_ = {
            400 : [1, 2, 11, 12, 13],
            200 : [0, 3, 4, 10, 14],
            100 : [5, 6, 7, 8, 9, 15, 23],
            0 : [16, 17, 18, 19, 20, 21, 22]
        }

        distance = self.distance
        time = self.time
        quantity = self.quantity
        
        code_fee_key = list(code_fee_.keys())

        distance_fee_key = list(distance_fee_.keys())
        time_fee_key = list(time_fee_.keys())

        distance_weight = -1 
        time_weight = -1
        quantity_weight = -1

        ## quantity_weight
        if quantity >= 100000:
            quantity_weight = 0

        else:
            for i in range(len(code_fee_key) -1 ):
                if (code_fee_key[i] > quantity) and (code_fee_key[i+1] <= quantity):
                    quantity_lower = code_fee_key[i+1]
                    quantity_upper = code_fee_key[i]

                    quantity_weight = code_fee_[quantity_lower] + 20 * (quantity - quantity_lower) / (quantity_upper - quantity_lower)

        distance_fee_ = {
            400 : 500,
            300 : 400,
            100 : 300,
            50 : 200,
            0 : 0
        }

        ## distance_weight
        if distance >= 400:
            distance_weight = 400
        else:
            for i in range(len(distance_fee_key) -1 ):
                if (distance_fee_key[i] > distance) and (distance_fee_key[i+1] <= distance):
                    distance_lower = distance_fee_key[i+1]
                    distance_upper = distance_fee_key[i]


                    distance_weight = distance_fee_[distance_lower] + (distance_fee_[distance_upper] - distance_fee_[distance_lower]) * (distance - distance_lower) / (distance_upper - distance_lower)

        ## time_weight
        for i in time_fee_key:
            if time in time_fee_[i]:
                time_weight = i

        total = distance_weight + time_weight + quantity_weight
        return distance_weight, time_weight, quantity_weight, total

# %%
a, b, c, d = set_fee(np.array([100, 0, 10000])).set_fee()
# Out:
# [100000, 50000, 30000, 20000, 10000, 5000, 3000, 2000, 1000, 500, 0]

# %%
print(a)
# Out:
# 300.0

# %%
with open("./server/model/set_fee_model2.pickle", "wb") as f:
    pickle.dump(set_fee, f, pickle.HIGHEST_PROTOCOL)

# %%
with open("./server/model/set_fee_model2.pickle", "rb") as f:
    set_fee = pickle.load(f)

# %%
# !pip install mymod
from mymod import *
# Out:
# Collecting mymod
#   Downloading mymod-1.0.tar.gz (741 bytes)
# Building wheels for collected packages: mymod
#   Building wheel for mymod (setup.py): started
#   Building wheel for mymod (setup.py): finished with status 'done'
#   Created wheel for mymod: filename=mymod-1.0-py3-none-any.whl size=1130 sha256=75761112247838d4ff0ff20c27e8d588b6b9d672648cf119426273c47a93102c
#   Stored in directory: c:\users\sb\appdata\local\pip\cache\wheels\69\98\cb\f2653f505f8a67e788835252aced4e0734f0545ba5a6f6fcd8
# Successfully built mymod
# Installing collected packages: mymod
# Successfully installed mymod-1.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-133-fdc389b730ec> in <module>
#       1 get_ipython().system('pip install mymod')
# ----> 2 from mymod import *
#
# ModuleNotFoundError: No module named 'mymod'

# %%
set_hour = []
for i in range(len(set_fee_df)):

    set_hour.append(set_fee_df["datetime"][i].hour)

set_fee_df["time"] = set_hour

# %%
train_x = set_fee_df[["distance", "time", "code_value"]].iloc[:120000, :]
train_y = set_fee_df[["result"]].iloc[:120000, :]

test_x = set_fee_df[["distance", "time", "code_value"]].iloc[120000:, :]
test_y = set_fee_df[["result"]].iloc[120000:, :]

# %%
rfg = RandomForestRegressor(max_depth=15)

rfg.fit(train_x, train_y)
rfg_pred = rfg.predict(test_x)
print("mae : ", mean_absolute_error(rfg_pred, test_y), "mse : ", mean_squared_error(rfg_pred, test_y))
# Out:
# mae :  0.27440773766344745 mse :  2.5749149376724842

# %%
test_x
# Out:
#                        distance  time  code_value
# 2021-03-03 02:07:55   82.054098     2      100000
# 2021-03-20 17:21:29  345.667122    17      100000
# 2021-04-08 01:06:42  345.667122     1      100000
# 2021-05-31 10:00:13   49.001604    10       36071
# 2021-03-10 05:59:40   62.113800     5      100000
# ...                         ...   ...         ...
# 2021-03-14 03:51:56   60.870158     3      100000
# 2021-03-08 16:10:52  254.217086    16       58814
# 2021-03-23 06:54:53  252.141436     6      100000
# 2021-04-11 09:10:58   53.283066     9      100000
# 2021-06-27 05:52:19  195.880357     5      100000
#
# [30000 rows x 3 columns]

# %%
rfg_pred
# Out:
# array([535.        , 354.        , 754.00006826, ..., 323.10837834,
#        293.        , 352.        ])

# %%
rfg.predict([[82, 2, 100]])
# Out:
# array([701.81])

# %%
test_y["result"][0]
# Out:
# 535

# %%
rfg.feature_importances_[0], rfg.feature_importances_[1], rfg.feature_importances_[2]
# Out:
# (0.3849871100716656, 0.6028915000885524, 0.012121389839782056)

# %%
rfg.feature_importances_
# Out:
# array([0.38498711, 0.6028915 , 0.01212139])

# %%
initial_fee = rfg.predict([[82, 17, 100]])[0]

# %%
distance_weight = (initial_fee) * \
    rfg.feature_importances_[0]
time_weight = (initial_fee) * rfg.feature_importances_[1]
discount_weight = (initial_fee) * \
    rfg.feature_importances_[2]

# %%
distance_weight, time_weight, discount_weight
# Out:
# (114.07168071423452, 178.6367514762381, 3.5915678095274233)

# %%
svr = SVR()
rfg = RandomForestRegressor()
abr = AdaBoostRegressor()
dtr = DecisionTreeRegressor()

# %%
svr.fit(train_x, train_y)
svr_pred = svr.predict(test_x)
print("mae : ", mean_absolute_error(svr_pred, test_y), "mse : ", mean_squared_error(svr_pred, test_y))
# Out:
# mae :  148.82041615345642 mse :  32994.02431502477

# %%
rfg.fit(train_x, train_y)
rfg_pred = rfg.predict(test_x)
print("mae : ", mean_absolute_error(rfg_pred, test_y), "mse : ", mean_squared_error(rfg_pred, test_y))
# Out:
# mae :  0.17556500000000344 mse :  2.3782131166666733

# %%
abr.fit(train_x, train_y)
abr_pred = abr.predict(test_x)
print("mae : ", mean_absolute_error(abr_pred, test_y), "mse : ", mean_squared_error(abr_pred, test_y))
# Out:
# mae :  88.33954944712637 mse :  9862.69457904521

# %%
dtr.fit(train_x, train_y)
dtr_pred = dtr.predict(test_x)
print("mae : ", mean_absolute_error(dtr_pred, test_y), "mse : ", mean_squared_error(dtr_pred, test_y))
# Out:
# mae :  0.14566666666666667 mse :  2.6778666666666666

# %%
batch_size = 100

dnn = Sequential()
dnn.add(Dense(units=64, activation="relu", input_shape=(batch_size, 3, )))
dnn.add(Dense(32))
dnn.add(Dense(1))

dnn.compile(loss="mean_squared_error", optimizer="adam")

# %%
dnn.fit(train_x, train_y, batch_size = batch_size, epochs=500, verbose= 2)
# Out:
# Epoch 1/500
# 1200/1200 - 1s - loss: 219856.8438
# Epoch 2/500
# 1200/1200 - 1s - loss: 213933.0781
# Epoch 3/500
# 1200/1200 - 1s - loss: 210907.2188
# Epoch 4/500
# 1200/1200 - 1s - loss: 206851.9688
# Epoch 461/500
# 1200/1200 - 1s - loss: 22853.5703
# Epoch 462/500
# 1200/1200 - 1s - loss: 23011.8770
# Epoch 463/500
# 1200/1200 - 1s - loss: 22940.4141
# Epoch 464/500
# 1200/1200 - 1s - loss: 22803.5098
# Epoch 465/500
# 1200/1200 - 1s - loss: 22815.3984
# Epoch 466/500
# 1200/1200 - 1s - loss: 22949.6348
# Epoch 467/500
# 1200/1200 - 1s - loss: 22831.9355
# Epoch 468/500
# 1200/1200 - 1s - loss: 22876.5605
# Epoch 469/500
# 1200/1200 - 1s - loss: 22870.8691
# Epoch 470/500
# 1200/1200 - 1s - loss: 22789.7305
# Epoch 471/500
# 1200/1200 - 1s - loss: 23145.4531
# Epoch 472/500
# 1200/1200 - 1s - loss: 22807.9004
# Epoch 473/500
# 1200/1200 - 1s - loss: 22936.2715
# Epoch 474/500
# 1200/1200 - 1s - loss: 22802.8613
# Epoch 475/500
# 1200/1200 - 1s - loss: 22890.2988
# Epoch 476/500
# 1200/1200 - 1s - loss: 22912.9688
# Epoch 477/500
# 1200/1200 - 1s - loss: 22905.5488
# Epoch 478/500
# 1200/1200 - 1s - loss: 22853.7344
# Epoch 479/500
# 1200/1200 - 1s - loss: 22819.0273
# Epoch 480/500
# 1200/1200 - 1s - loss: 22818.9512
# Epoch 481/500
# 1200/1200 - 1s - loss: 22834.7090
# Epoch 482/500
# 1200/1200 - 1s - loss: 22742.1074
# Epoch 483/500
# 1200/1200 - 1s - loss: 22832.3340
# Epoch 484/500
# 1200/1200 - 1s - loss: 36981.5938
# Epoch 485/500
# 1200/1200 - 1s - loss: 28112.6797
# Epoch 486/500
# 1200/1200 - 1s - loss: 22704.7656
# Epoch 487/500
# 1200/1200 - 1s - loss: 22768.6094
# Epoch 488/500
# 1200/1200 - 1s - loss: 22741.8789
# Epoch 489/500
# 1200/1200 - 1s - loss: 22730.1699
# Epoch 490/500
# 1200/1200 - 1s - loss: 22665.0703
# Epoch 491/500
# 1200/1200 - 1s - loss: 22807.6836
# Epoch 492/500
# 1200/1200 - 1s - loss: 22963.3555
# Epoch 493/500
# 1200/1200 - 1s - loss: 22735.2695
# Epoch 494/500
# 1200/1200 - 2s - loss: 22759.2168
# Epoch 495/500
# 1200/1200 - 2s - loss: 32458.1914
# Epoch 496/500
# 1200/1200 - 2s - loss: 27317.1035
# Epoch 497/500
# 1200/1200 - 2s - loss: 22840.5332
# Epoch 498/500
# 1200/1200 - 2s - loss: 22903.0352
# Epoch 499/500
# 1200/1200 - 2s - loss: 22802.8711
# Epoch 500/500
# 1200/1200 - 2s - loss: 22840.7617

# %%
pred = dnn.predict(test_x)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 100, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 100, 3), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 3).

# %%
mean_absolute_error(pred, test_y), mean_squared_error(pred, test_y)
# Out:
# (126.04838692220052, 24018.078190347012)

# %%
with open("./server/model/set_fee_mode.pickle", "wb") as f:
    pickle.dump(rfg, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# import time
#
# a = 10
# while True:
#     time.sleep(10)
#
#     print(a)
#     a= a + 1
