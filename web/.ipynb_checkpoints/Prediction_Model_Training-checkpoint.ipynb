# %%
import pandas as pd 
import numpy as np
import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import Dense, Input, LSTM, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, SGD
import warnings
from keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
warnings.filterwarnings(action='ignore')

# %%
# %run "./preprocessing.ipynb"
# Out:
# Done !!

# %%
hour_data = e_commerce_fc_data[["품목수량"]].resample("1H").count()

# %%
hour_data
# Out:
#                      품목수량
# 2021-03-01 00:00:00   386
# 2021-03-01 01:00:00   416
# 2021-03-01 02:00:00   522
# 2021-03-01 03:00:00   501
# 2021-03-01 04:00:00   412
# ...                   ...
# 2021-06-30 19:00:00   856
# 2021-06-30 20:00:00   990
# 2021-06-30 21:00:00  1097
# 2021-06-30 22:00:00  1154
# 2021-06-30 23:00:00   936
#
# [2928 rows x 1 columns]

# %%
plt.figure(figsize=(15, 5))
plt.plot(hour_data)

# %%
## scale

scaler = MinMaxScaler()
scale_data = scaler.fit_transform(np.array(hour_data["품목수량"]).reshape(-1, 1))

scale_data = pd.DataFrame(scale_data)

# %%
## train test split 

train_set = scale_data.iloc[:2400, :]
test_set = scale_data.iloc[2400:, :]

# %%
## set window size
STEP = 12

def window_size(data, step):
    
    x, y = [], []
    for i in range(len(data)-step-1):
        x.append(data.iloc[i:(i+step), 0])
        y.append(data.iloc[i+step, 0]) 
        
    
    return np.array(x).reshape(len(x), step, 1), np.array(y)

# %%
train_x, train_y = window_size(train_set, STEP)
test_x, test_y = window_size(test_set, STEP)

# %%
### MAKE MODEL 
def setModel(batch_size, step):
    model = Sequential()
    model.add(LSTM(64, batch_input_shape = (batch_size, step, 1), stateful = True, return_sequences=True))
    model.add(LSTM(32, batch_input_shape = (batch_size, step, 1), stateful = True, return_sequences=True))
    model.add(LSTM(16, batch_input_shape = (batch_size, step, 1), stateful = True))
    model.add(Dense(1))

    model.compile(loss="mean_squared_error", metrics = ["mse"], optimizer="adam")
    
    return model

# %%
### Callbacks 
CALLBACKS = [EarlyStopping(monitor='mse', patience = 5),
            ModelCheckpoint(filepath="./server/model/model.h5", monitor="mse", save_best_only = True)]

# %%
### model Load 
batch_size = 1
model = setModel(batch_size, 12)

# %%
### model Train
model.fit(train_x, train_y, epochs=1000, batch_size = batch_size, callbacks = CALLBACKS, verbose=1)
# Out:
# Epoch 1/1000
# 2387/2387 [==============================] - 32s 10ms/step - loss: 0.0041 - mse: 0.0041
# Epoch 2/1000
# 2387/2387 [==============================] - 25s 11ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 3/1000
# 2387/2387 [==============================] - 25s 10ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 4/1000
# 2387/2387 [==============================] - 24s 10ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 5/1000
# 2387/2387 [==============================] - 23s 10ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 6/1000
# 2387/2387 [==============================] - 25s 10ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 7/1000
# 2387/2387 [==============================] - 24s 10ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 8/1000
# 2387/2387 [==============================] - 25s 10ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 9/1000
# 2387/2387 [==============================] - 26s 11ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 10/1000
# 2387/2387 [==============================] - 27s 11ms/step - loss: 0.0017 - mse: 0.0017 0s - loss: 0.001
# Epoch 11/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 12/1000
# 2387/2387 [==============================] - 26s 11ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 13/1000
# 2387/2387 [==============================] - 25s 11ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 14/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 15/1000
# 2387/2387 [==============================] - 25s 11ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 16/1000
# 2387/2387 [==============================] - 27s 11ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 17/1000
# 2387/2387 [==============================] - 26s 11ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 18/1000
# 2387/2387 [==============================] - 26s 11ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 19/1000
# 2387/2387 [==============================] - 27s 11ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 20/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 21/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 22/1000
# 2387/2387 [==============================] - 26s 11ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 23/1000
# 2387/2387 [==============================] - 30s 13ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 24/1000
# 2387/2387 [==============================] - 27s 11ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 25/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 26/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 27/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 28/1000
# 2387/2387 [==============================] - 29s 12ms/step - loss: 0.0022 - mse: 0.0022
# Epoch 29/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0011 - mse: 0.0011
# Epoch 30/1000
# 2387/2387 [==============================] - 31s 13ms/step - loss: 0.0013 - mse: 0.0013 1s
# Epoch 31/1000
# 2387/2387 [==============================] - 32s 13ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 32/1000
# 2387/2387 [==============================] - 30s 12ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 33/1000
# 2387/2387 [==============================] - 31s 13ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 34/1000
# 2387/2387 [==============================] - 24s 10ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 35/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 36/1000
# 2387/2387 [==============================] - 31s 13ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 37/1000
# 2387/2387 [==============================] - 28s 12ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 38/1000
# 2387/2387 [==============================] - 29s 12ms/step - loss: 0.0016 - mse: 0.0016 1s - loss:
# Epoch 39/1000
# 2387/2387 [==============================] - 36s 15ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 40/1000
# 2387/2387 [==============================] - 30s 13ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 41/1000
# 2387/2387 [==============================] - 29s 12ms/step - loss: 0.0010 - mse: 0.0010
# Epoch 42/1000
# 2387/2387 [==============================] - 32s 14ms/step - loss: 0.0012 - mse: 0.0012
# Epoch 43/1000
# 2387/2387 [==============================] - 25s 11ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 44/1000
# 2387/2387 [==============================] - 32s 14ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 45/1000
# 2387/2387 [==============================] - 27s 11ms/step - loss: 0.0014 - mse: 0.0014
